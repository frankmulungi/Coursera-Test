# %% [markdown]
# <a href="https://colab.research.google.com/github/frankmulungi/Coursera-Test/blob/master/apiprojectusing_mslearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import requests
from pprint import pprint

pokemon_number = input('What is your favourite pokemon number?')

url = f'https://learn.microsoft.com/api/catalog/?type=modules,learningPaths'

response = requests.get(url)
print(response)
# Out:
# What is your favourite pokemon number?34
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
pokemon = response.json()
pprint(pokemon)
# Out:
# Streaming output truncated to the last 5000 lines.
#               'title': 'Introduction to compliance tools in Microsoft 365',
#               'type': 'module',
#               'uid': 'learn-m365.meet-compliance-with-m365',
#               'units': ['learn-m365.compliance-m365.2-common-compliance',
#                         'learn-m365.compliance-m365.3-assess-your-compliance',
#                         'learn-m365.compliance-m365.4-data-governance',
#                         'learn-m365.compliance-m365.4-enable-encryption',
#                         'learn-m365.compliance-m365.5-enforce-zero-standing',
#                         'learn-m365.compliance-m365.6-respond-to-data-discovery',
#                         'learn-m365.compliance-m365.4-microsoft-compliance-center',
#                         'learn-m365.compliance-m365.5-summary-and-knowledge-check'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/compliance-in-m365/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 37,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/add-domain-microsoft-365/1-introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/add-domain-microsoft-365.svg',
#               'last_modified': '2023-06-21T17:03:00+00:00',
#               'levels': ['intermediate'],
#               'locale': 'en-us',
#               'number_of_children': 7,
#               'popularity': 0.573492660952682,
#               'products': ['m365', 'office-365'],
#               'rating': {'average': 4.76, 'count': 103},
#               'roles': ['administrator',
#                         'solution-architect',
#                         'technology-manager'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'subjects': ['business-applications',
#                            'compliance',
#                            'identity-access',
#                            'insider-risk',
#                            'it-management-monitoring',
#                            'modern-work',
#                            'productivity',
#                            'security',
#                            'threat-protection'],
#               'summary': 'This module provides instruction on how to add a '
#                          'custom domain to your Microsoft 365 deployment. It '
#                          'also examines the DNS requirements that are '
#                          'necessary to support a new domain.',
#               'title': 'Add a custom domain in Microsoft 365',
#               'type': 'module',
#               'uid': 'learn.wwl.add-domain-microsoft-365',
#               'units': ['learn.wwl.add-domain-microsoft-365.introduction',
#                         'learn.wwl.add-domain-microsoft-365.plan-custom-domain-microsoft-365',
#                         'learn.wwl.add-domain-microsoft-365.plan-dns-zones-custom-domain',
#                         'learn.wwl.add-domain-microsoft-365.plan-dns-record-requirements-custom-domain',
#                         'learn.wwl.add-domain-microsoft-365.create-custom-domain-microsoft-365',
#                         'learn.wwl.add-domain-microsoft-365.knowledge-check',
#                         'learn.wwl.add-domain-microsoft-365.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/add-domain-microsoft-365/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 38,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/viva-connections-launch-and-monitor/1-introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-badge.svg',
#               'last_modified': '2023-05-18T17:01:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 7,
#               'popularity': 0.355119073172438,
#               'products': ['viva', 'viva-connections', 'm365'],
#               'rating': {'average': 4.8, 'count': 40},
#               'roles': ['administrator', 'student'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'subjects': ['modern-work',
#                            'employee-engagement',
#                            'employee-management',
#                            'collaboration',
#                            'productivity'],
#               'summary': 'Learn how to test, launch, evaluate, and monitor '
#                          'Viva Connections.',
#               'title': 'Launch and monitor Viva Connections',
#               'type': 'module',
#               'uid': 'learn-m365.viva-connections-launch-and-monitor',
#               'units': ['learn-m365.viva-connections-launch-and-monitor.introduction',
#                         'learn-m365.viva-connections-launch-and-monitor.test-viva-connections-before-launch',
#                         'learn-m365.viva-connections-launch-and-monitor.announce-viva-connections-to-your-organization',
#                         'learn-m365.viva-connections-launch-and-monitor.help-your-organization-manage-change',
#                         'learn-m365.viva-connections-launch-and-monitor.use-metrics-to-evaluate',
#                         'learn-m365.viva-connections-launch-and-monitor.knowledge-check',
#                         'learn-m365.viva-connections-launch-and-monitor.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/viva-connections-launch-and-monitor/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 69,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/msgraph-changenotifications-trackchanges/1-introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/msgraph-changenotifications-trackchanges.svg',
#               'last_modified': '2023-05-18T17:01:00+00:00',
#               'levels': ['intermediate'],
#               'locale': 'en-us',
#               'number_of_children': 8,
#               'popularity': 0.414081184661088,
#               'products': ['m365', 'ms-graph'],
#               'rating': {'average': 4.82, 'count': 552},
#               'roles': ['developer'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'subjects': ['development-tools'],
#               'summary': 'Learn how to with change notifications (webhooks) '
#                          'and track changes (delta query) in the Microsoft '
#                          'Graph.',
#               'title': 'Use Change Notifications and Track Changes with '
#                        'Microsoft Graph',
#               'type': 'module',
#               'uid': 'learn-m365.msgraph-changenotifications-trackchanges',
#               'units': ['learn-m365.msgraph-changenotifications-trackchanges.1-introduction',
#                         'learn-m365.msgraph-changenotifications-trackchanges.2-graph-overview-create-app',
#                         'learn-m365.msgraph-changenotifications-trackchanges.3-exercise-create-app',
#                         'learn-m365.msgraph-changenotifications-trackchanges.4-change-notifications',
#                         'learn-m365.msgraph-changenotifications-trackchanges.5-exercise-change-notifications',
#                         'learn-m365.msgraph-changenotifications-trackchanges.6-track-changes',
#                         'learn-m365.msgraph-changenotifications-trackchanges.7-exercise-track-changes',
#                         'learn-m365.msgraph-changenotifications-trackchanges.8-summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/msgraph-changenotifications-trackchanges/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 19,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/explore-device-encryption-features/1-introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/encryption-explore-features.svg',
#               'last_modified': '2023-05-18T17:01:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 7,
#               'popularity': 0.432439536813207,
#               'products': ['windows'],
#               'rating': {'average': 4.83, 'count': 76},
#               'roles': ['administrator'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'subjects': ['device-management'],
#               'summary': 'This module explains the benefits of using '
#                          'encryption to protect drives and files against '
#                          'unauthorized access.',
#               'title': 'Explore device encryption features',
#               'type': 'module',
#               'uid': 'learn.wwl.explore-device-encryption-features',
#               'units': ['learn.wwl.explore-device-encryption-features.introduction',
#                         'learn.wwl.explore-device-encryption-features.examine-bitlocker',
#                         'learn.wwl.explore-device-encryption-features.evaluate-bitlocker-tpms',
#                         'learn.wwl.explore-device-encryption-features.recover-bitlocker-encrypted-drive',
#                         'learn.wwl.explore-device-encryption-features.assess-encrypting-files-system',
#                         'learn.wwl.explore-device-encryption-features.knowledge-check',
#                         'learn.wwl.explore-device-encryption-features.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/explore-device-encryption-features/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 20,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/microsoft-search-edu/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/microsoft-search-edu.svg',
#               'last_modified': '2023-05-18T17:01:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 7,
#               'popularity': 0.405911828390652,
#               'products': ['m365', 'office', 'windows', 'bing'],
#               'rating': {'average': 4.74, 'count': 80},
#               'roles': ['administrator',
#                         'business-owner',
#                         'functional-consultant',
#                         'technology-manager'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'subjects': ['search-ads-news'],
#               'summary': 'Overview of the search experience for schools, '
#                          'including the custom results available to students '
#                          'and teachers, and the settings available to '
#                          'customize school and web results for your '
#                          'organization.',
#               'title': 'Use and customize Microsoft Search for schools',
#               'type': 'module',
#               'uid': 'learn-m365.microsoft-search-edu',
#               'units': ['learn-m365.microsoft-search-edu.introduction',
#                         'learn-m365.microsoft-search-edu.where-to-find-school-results',
#                         'learn-m365.microsoft-search-edu.school-results-answers',
#                         'learn-m365.microsoft-search-edu.help-keep-school-data-safe',
#                         'learn-m365.microsoft-search-edu.customize-search-experience',
#                         'learn-m365.microsoft-search-edu.knowledge-check',
#                         'learn-m365.microsoft-search-edu.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/microsoft-search-edu/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 40,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/implement-security-for-microsoft-teams/01-introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/teams-implement-security.svg',
#               'last_modified': '2023-05-18T17:01:00+00:00',
#               'levels': ['intermediate'],
#               'locale': 'en-us',
#               'number_of_children': 9,
#               'popularity': 0.514721597332299,
#               'products': ['m365', 'office-teams'],
#               'rating': {'average': 4.76, 'count': 975},
#               'roles': ['administrator'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'subjects': ['collaboration', 'security'],
#               'summary': 'Implement security for Microsoft Teams',
#               'title': 'Implement security for Microsoft Teams',
#               'type': 'module',
#               'uid': 'learn.wwl.implement-security-for-microsoft-teams',
#               'units': ['learn.wwl.implement-security-for-microsoft-teams.introduction',
#                         'learn.wwl.implement-security-for-microsoft-teams.configure-conditional-access-multifactor-authentication',
#                         'learn.wwl.implement-security-for-microsoft-teams.configure-safe-attachments',
#                         'learn.wwl.implement-security-for-microsoft-teams.configure-safe-links',
#                         'learn.wwl.implement-security-for-microsoft-teams.examine-defender-cloud-app',
#                         'learn.wwl.implement-security-for-microsoft-teams.monitor-security-reports',
#                         'learn.wwl.implement-security-for-microsoft-teams.enhanced-encryption-policies',
#                         'learn.wwl.implement-security-for-microsoft-teams.knowledge-check',
#                         'learn.wwl.implement-security-for-microsoft-teams.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/implement-security-for-microsoft-teams/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 24,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/protect-against-malicious-attacks-unauthorized-access-with-microsoft-edge/1-introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/protect-against-malicious-attacks-and-unauthorized-access-with-microsoft-edge.svg',
#               'last_modified': '2023-05-18T17:01:00+00:00',
#               'levels': ['intermediate'],
#               'locale': 'en-us',
#               'number_of_children': 7,
#               'popularity': 0.427511988117927,
#               'products': ['m365',
#                            'office-365',
#                            'microsoft-edge',
#                            'internet-explorer'],
#               'rating': {'average': 4.78, 'count': 485},
#               'roles': ['administrator'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'subjects': ['identity-access', 'threat-protection'],
#               'summary': 'Protect against malicious attacks and unauthorized '
#                          'access with Microsoft Edge',
#               'title': 'Protect against malicious attacks and unauthorized '
#                        'access with Microsoft Edge',
#               'type': 'module',
#               'uid': 'learn.wwl.protect-against-malicious-attacks-unauthorized-access-with-microsoft-edge',
#               'units': ['learn.wwl.protect-against-malicious-attacks-unauthorized-access-with-microsoft-edge.introduction',
#                         'learn.wwl.protect-against-malicious-attacks-unauthorized-access-with-microsoft-edge.understand-secure-foundations-of',
#                         'learn.wwl.protect-against-malicious-attacks-unauthorized-access-with-microsoft-edge.intercept-malicious-attacks-defender-smartscreen',
#                         'learn.wwl.protect-against-malicious-attacks-unauthorized-access-with-microsoft-edge.enhance-browser-security-defender-application-guard',
#                         'learn.wwl.protect-against-malicious-attacks-unauthorized-access-with-microsoft-edge.manage-controls-policies-for-edge-microsoft-endpoint-manager',
#                         'learn.wwl.protect-against-malicious-attacks-unauthorized-access-with-microsoft-edge.knowledge-check',
#                         'learn.wwl.protect-against-malicious-attacks-unauthorized-access-with-microsoft-edge.summary-resources'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/protect-against-malicious-attacks-unauthorized-access-with-microsoft-edge/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 62,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/sharepoint-spfx-extensions/1-introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/sharepoint-spfx-extensions.svg',
#               'last_modified': '2023-05-18T17:01:00+00:00',
#               'levels': ['intermediate'],
#               'locale': 'en-us',
#               'number_of_children': 8,
#               'popularity': 0.395320106950477,
#               'products': ['m365', 'office-sp-framework'],
#               'rating': {'average': 4.72, 'count': 146},
#               'roles': ['developer'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'subjects': ['cloud-computing', 'collaboration'],
#               'summary': 'Learn how to extend the SharePoint user interface '
#                          'with SharePoint Framework extensions.',
#               'title': 'Extend the SharePoint user interface with SharePoint '
#                        'Framework extensions',
#               'type': 'module',
#               'uid': 'learn-m365.sharepoint-spfx-extensions',
#               'units': ['learn-m365.sharepoint-spfx-extensions.1-introduction',
#                         'learn-m365.sharepoint-spfx-extensions.2-extensions-overview-app-customizer',
#                         'learn-m365.sharepoint-spfx-extensions.3-exercise-application-customizer',
#                         'learn-m365.sharepoint-spfx-extensions.4-field-customizer-extension',
#                         'learn-m365.sharepoint-spfx-extensions.5-exercise-field-customizer',
#                         'learn-m365.sharepoint-spfx-extensions.6-command-set-extension',
#                         'learn-m365.sharepoint-spfx-extensions.7-exercise-command-set-customizer',
#                         'learn-m365.sharepoint-spfx-extensions.8-summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/sharepoint-spfx-extensions/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 74,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/sharepoint-spfx-web-part-property-pane/1-introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/sharepoint-spfx-web-part-property-pane.svg',
#               'last_modified': '2023-05-18T17:01:00+00:00',
#               'levels': ['intermediate'],
#               'locale': 'en-us',
#               'number_of_children': 8,
#               'popularity': 0.421946904314687,
#               'products': ['m365', 'office-sp-framework'],
#               'rating': {'average': 4.73, 'count': 195},
#               'roles': ['developer'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'subjects': ['development-tools'],
#               'summary': 'Learn how to enable web part configurations with '
#                          'property panes in the SharePoint Framework.',
#               'title': 'Enable SharePoint Framework web part configuration '
#                        'with property panes',
#               'type': 'module',
#               'uid': 'learn-m365.sharepoint-spfx-web-part-property-pane',
#               'units': ['learn-m365.sharepoint-spfx-web-part-property-pane.1-introduction',
#                         'learn-m365.sharepoint-spfx-web-part-property-pane.2-property-pane-overview',
#                         'learn-m365.sharepoint-spfx-web-part-property-pane.3-exercise-web-part-property-pane',
#                         'learn-m365.sharepoint-spfx-web-part-property-pane.4-build-custom-property-pane-controls',
#                         'learn-m365.sharepoint-spfx-web-part-property-pane.5-exercise-build-custom-controls',
#                         'learn-m365.sharepoint-spfx-web-part-property-pane.6-pnp-controls',
#                         'learn-m365.sharepoint-spfx-web-part-property-pane.7-exercise-pnp-controls',
#                         'learn-m365.sharepoint-spfx-web-part-property-pane.8-summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/sharepoint-spfx-web-part-property-pane/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 24,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/m365-bring-all-together-engaging-virtual-events/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/bringing-it-all-together-for-engaging-virtual-events.svg',
#               'last_modified': '2023-07-05T23:03:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 7,
#               'popularity': 0.245879566158506,
#               'products': ['office-teams', 'viva-engage'],
#               'rating': {'average': 4.79, 'count': 133},
#               'roles': ['business-user', 'administrator'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'subjects': ['modern-work', 'collaboration'],
#               'summary': 'Learn best practices for producing, presenting, '
#                          'moderating, and attending a virtual event in '
#                          'Microsoft Teams or Microsoft 365.',
#               'title': 'Bringing it all together for engaging virtual events '
#                        'in Microsoft 365',
#               'type': 'module',
#               'uid': 'learn-m365-pr.bringing-all-together-engaging-virtual-events',
#               'units': ['learn-m365-pr.bringing-all-together-engaging-virtual-events.introduction',
#                         'learn-m365-pr.bringing-all-together-engaging-virtual-events.produce-virtual-event',
#                         'learn-m365-pr.bringing-all-together-engaging-virtual-events.present-virtual-event',
#                         'learn-m365-pr.bringing-all-together-engaging-virtual-events.moderate-virtual-event',
#                         'learn-m365-pr.bringing-all-together-engaging-virtual-events.attend-virtual-event',
#                         'learn-m365-pr.bringing-all-together-engaging-virtual-events.knowledge-check',
#                         'learn-m365-pr.bringing-all-together-engaging-virtual-events.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/m365-bring-all-together-engaging-virtual-events/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 58,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/independent-learning-math-tools-onenote/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/independent-learning-math-tools-onenote.svg',
#               'last_modified': '2023-05-11T23:02:00+00:00',
#               'levels': ['intermediate'],
#               'locale': 'en-us',
#               'number_of_children': 12,
#               'popularity': 0.563001519534988,
#               'products': ['office-onenote'],
#               'rating': {'average': 4.81, 'count': 2743},
#               'roles': ['k-12-educator'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'Educators will understand how the OneNote Math '
#                          'button allows students to see the steps to solve an '
#                          'equation and helps them become independent learners.',
#               'title': 'Independent learning with math tools in OneNote',
#               'type': 'module',
#               'uid': 'learn.mec.independent-learning-math-tools-onenote',
#               'units': ['learn.mec.independent-learning-math-tools-onenote.introduction',
#                         'learn.mec.independent-learning-math-tools-onenote.math-assistant-onenote',
#                         'learn.mec.independent-learning-math-tools-onenote.personalize-learning-process',
#                         'learn.mec.independent-learning-math-tools-onenote.math-tool-brings-equations-life',
#                         'learn.mec.independent-learning-math-tools-onenote.math-assistant-does-much-more',
#                         'learn.mec.independent-learning-math-tools-onenote.ink-not-ink',
#                         'learn.mec.independent-learning-math-tools-onenote.check-settings',
#                         'learn.mec.independent-learning-math-tools-onenote.digital-ruler-fingertips',
#                         'learn.mec.independent-learning-math-tools-onenote.onenote-endless-possibilities',
#                         'learn.mec.independent-learning-math-tools-onenote.math-curriculum-delivered-onenote',
#                         'learn.mec.independent-learning-math-tools-onenote.knowledge-check',
#                         'learn.mec.independent-learning-math-tools-onenote.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/independent-learning-math-tools-onenote/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 47,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/accessibility-special-education-online-learning-equity/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/accessibility-special-education-online-learning-equity.svg',
#               'last_modified': '2023-05-11T23:02:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 11,
#               'popularity': 0.5743809774278,
#               'products': ['office-teams', 'office-365', 'office-onenote'],
#               'rating': {'average': 4.81, 'count': 2439},
#               'roles': ['k-12-educator', 'school-leader'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'Learn to teach with the accessibility tools in '
#                          'Windows 10, Office 365, and apps including Teams, '
#                          'Immersive Reader, Math Tools, Word, Translator, and '
#                          'OneNote. Dive deep into areas of student need to '
#                          'learn about specific opportunities and '
#                          'considerations for special education and online '
#                          'learning.  ',
#               'title': 'Accessibility, special education, and online learning: '
#                        'Supporting\xa0equity in a remote learning environment',
#               'type': 'module',
#               'uid': 'learn.mec.accessibility-special-education-online-learning-equity',
#               'units': ['learn.mec.accessibility-special-education-online-learning-equity.introduction',
#                         'learn.mec.accessibility-special-education-online-learning-equity.how-help-students-with-learning-differences',
#                         'learn.mec.accessibility-special-education-online-learning-equity.how-help-students-with-visual-limitations',
#                         'learn.mec.accessibility-special-education-online-learning-equity.how-help-students-with-hearing-limitations',
#                         'learn.mec.accessibility-special-education-online-learning-equity.how-help-students-with-mobility-challenges',
#                         'learn.mec.accessibility-special-education-online-learning-equity.how-help-students-who-are-neurodiverse',
#                         'learn.mec.accessibility-special-education-online-learning-equity.how-help-students-with-mental-health',
#                         'learn.mec.accessibility-special-education-online-learning-equity.create-accessible-content',
#                         'learn.mec.accessibility-special-education-online-learning-equity.educator-tips',
#                         'learn.mec.accessibility-special-education-online-learning-equity.knowledge-check',
#                         'learn.mec.accessibility-special-education-online-learning-equity.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/accessibility-special-education-online-learning-equity/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 60,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/teaching-learning-education-transformation-framework/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/teaching-learning-education-transformation-framework.svg',
#               'last_modified': '2023-05-11T23:02:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 7,
#               'popularity': 0.422904135633142,
#               'products': ['office-teams'],
#               'rating': {'average': 4.83, 'count': 443},
#               'roles': ['k-12-educator', 'school-leader'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'In this module school leaders and educators learn to '
#                          'help students achieve their potential by taking a '
#                          'student-centered approach to explore all aspects of '
#                          'teaching and learning: curriculum, assessment, '
#                          'devices, and spaces with a focus on understanding '
#                          'and meeting the needs of all students.',
#               'title': 'Teaching and learning - Education Transformation '
#                        'Framework',
#               'type': 'module',
#               'uid': 'learn.mec.teaching-learning-education-transformation-framework',
#               'units': ['learn.mec.teaching-learning-education-transformation-framework.introduction',
#                         'learn.mec.teaching-learning-education-transformation-framework.student-centered-learning',
#                         'learn.mec.teaching-learning-education-transformation-framework.curriculum-and-assessment',
#                         'learn.mec.teaching-learning-education-transformation-framework.devices-for-learning',
#                         'learn.mec.teaching-learning-education-transformation-framework.learning-spaces',
#                         'learn.mec.teaching-learning-education-transformation-framework.knowledge-check',
#                         'learn.mec.teaching-learning-education-transformation-framework.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/teaching-learning-education-transformation-framework/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 58,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/collaborate-faster-microsoft-teams-higher-education-staff/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/collaborate-faster-microsoft-teams-higher-education-staff.svg',
#               'last_modified': '2023-05-11T23:02:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 13,
#               'popularity': 0.411596400353134,
#               'products': ['office-teams', 'office-onenote'],
#               'rating': {'average': 4.82, 'count': 351},
#               'roles': ['k-12-educator'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'Microsoft Staff and PLC Teams provide the perfect '
#                          'location to work with colleagues on projects, '
#                          'curriculum adoptions, and even university-wide '
#                          'initiatives. Administrators can communicate and '
#                          'collaborate with their faculty in one location. '
#                          'Policies and procedures, forms, instructions for '
#                          'various tasks and responsibilities, and more can all '
#                          'be shared within Teams for quick access.  Teams '
#                          'supports online meetings with screen share and '
#                          'whiteboard annotation that can be recorded, '
#                          'automatically saved, and transcribed in Stream. '
#                          'Whether your colleagues are down the hall or in '
#                          'another building across town, Staff and PLC Teams '
#                          'support collaboration among educators.',
#               'title': 'Collaborate faster using Microsoft Teams for higher '
#                        'education staff',
#               'type': 'module',
#               'uid': 'learn.mec.collaborate-faster-microsoft-teams-higher-education-staff',
#               'units': ['learn.mec.collaborate-faster-microsoft-teams-higher-education-staff.introduction',
#                         'learn.mec.collaborate-faster-microsoft-teams-higher-education-staff.staff-teams-effective-leadership-save-time',
#                         'learn.mec.collaborate-faster-microsoft-teams-higher-education-staff.use-microsoft-teams-any-device',
#                         'learn.mec.collaborate-faster-microsoft-teams-higher-education-staff.create-staff-members-anyone-team',
#                         'learn.mec.collaborate-faster-microsoft-teams-higher-education-staff.set-member-permissions',
#                         'learn.mec.collaborate-faster-microsoft-teams-higher-education-staff.leverage-chat-improved-communication',
#                         'learn.mec.collaborate-faster-microsoft-teams-higher-education-staff.create-channels',
#                         'learn.mec.collaborate-faster-microsoft-teams-higher-education-staff.add-content-channels-with-apps-tabs',
#                         'learn.mec.collaborate-faster-microsoft-teams-higher-education-staff.customize-staff-notebook',
#                         'learn.mec.collaborate-faster-microsoft-teams-higher-education-staff.use-online-meetings-connect-anytime-anywhere',
#                         'learn.mec.collaborate-faster-microsoft-teams-higher-education-staff.facilitate-collaboration-with-apps-guests',
#                         'learn.mec.collaborate-faster-microsoft-teams-higher-education-staff.knowledge-check',
#                         'learn.mec.collaborate-faster-microsoft-teams-higher-education-staff.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/collaborate-faster-microsoft-teams-higher-education-staff/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 13,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/start-anti-racism-journey/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/start-anti-racism-journey.svg',
#               'last_modified': '2023-07-17T17:07:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 7,
#               'popularity': 0.412191296229894,
#               'products': ['flip', 'office-onenote'],
#               'rating': {'average': 4.66, 'count': 175},
#               'roles': ['k-12-educator', 'school-leader'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'Understand the process that will be used as the '
#                          'learning path guides you through the anti-racism '
#                          'learning journey. This is the first module in a '
#                          'learning path and is intended to be taken in order '
#                          'in that path.',
#               'title': 'Start the anti-racism journey',
#               'type': 'module',
#               'uid': 'learn.mec.start-anti-racism-journey',
#               'units': ['learn.mec.start-anti-racism-journey.introduction',
#                         'learn.mec.start-anti-racism-journey.process-professional-learning-communities',
#                         'learn.mec.start-anti-racism-journey.team',
#                         'learn.mec.start-anti-racism-journey.additional-resources-for-learning',
#                         'learn.mec.start-anti-racism-journey.additional-resources-for-action',
#                         'learn.mec.start-anti-racism-journey.knowledge-check',
#                         'learn.mec.start-anti-racism-journey.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/start-anti-racism-journey/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 58,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/introduce-esports-education/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/introduce-esports-education.svg',
#               'last_modified': '2023-05-11T23:02:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 10,
#               'popularity': 0.425955267030857,
#               'products': ['minecraft'],
#               'rating': {'average': 4.77, 'count': 386},
#               'roles': ['k-12-educator'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'Support educators in understanding what esports '
#                          '(electronic sports) is and the role of esports in '
#                          'educational settings.',
#               'title': 'Introduce esports in education',
#               'type': 'module',
#               'uid': 'learn.mec.introduce-esports-education',
#               'units': ['learn.mec.introduce-esports-education.introduction',
#                         'learn.mec.introduce-esports-education.what-is-esports',
#                         'learn.mec.introduce-esports-education.global-audience-for-esports',
#                         'learn.mec.introduce-esports-education.benefits-of-esports',
#                         'learn.mec.introduce-esports-education.transferable-skills-in-esports-ecosystem',
#                         'learn.mec.introduce-esports-education.create-esports-clubs-in-your-school',
#                         'learn.mec.introduce-esports-education.scholastic-academic-esports',
#                         'learn.mec.introduce-esports-education.careers-pathways-in-esports',
#                         'learn.mec.introduce-esports-education.knowledge-check',
#                         'learn.mec.introduce-esports-education.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/introduce-esports-education/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 63,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/minecraft-place-first-blocks/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/minecraft-place-first-blocks.svg',
#               'last_modified': '2023-05-11T23:02:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 6,
#               'popularity': 0.63976102864525,
#               'products': ['minecraft'],
#               'rating': {'average': 4.77, 'count': 3167},
#               'roles': ['k-12-educator', 'school-leader'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'Build upon the skills learned in Minecraft 101 by '
#                          'continuing another build challenge introducing new '
#                          'in-game assessment tools and a multiplayer '
#                          'environment. Continue to look into the lesson '
#                          'planning process as a reflection.',
#               'title': "Minecraft 201: Let's modify together",
#               'type': 'module',
#               'uid': 'learn.mec.minecraft-place-first-blocks',
#               'units': ['learn.mec.minecraft-place-first-blocks.introduction',
#                         'learn.mec.minecraft-place-first-blocks.teach-build-furniture',
#                         'learn.mec.minecraft-place-first-blocks.release-build-furniture-house',
#                         'learn.mec.minecraft-place-first-blocks.reflect-debrief-build-your-furniture-lesson',
#                         'learn.mec.minecraft-place-first-blocks.knowledge-check',
#                         'learn.mec.minecraft-place-first-blocks.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/minecraft-place-first-blocks/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 75,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/accept-your-identity-anti-racism-journey/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/accept-your-identity-anti-racism-journey.svg',
#               'last_modified': '2023-07-17T17:07:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 8,
#               'popularity': 0.403396912118882,
#               'products': ['flip', 'office-onenote'],
#               'rating': {'average': 4.73, 'count': 129},
#               'roles': ['k-12-educator', 'school-leader'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'This module dives into personal identities, '
#                          'specifically discussing race, and how those '
#                          'identities have shaped our personal belief systems. '
#                          'This is the third module in a learning path and is '
#                          'intended to be taken in order in that path.',
#               'title': 'Accept your identity in the anti-racism journey',
#               'type': 'module',
#               'uid': 'learn.mec.accept-your-identity-anti-racism-journey',
#               'units': ['learn.mec.accept-your-identity-anti-racism-journey.introduction',
#                         'learn.mec.accept-your-identity-anti-racism-journey.norm-setting-review',
#                         'learn.mec.accept-your-identity-anti-racism-journey.storytelling',
#                         'learn.mec.accept-your-identity-anti-racism-journey.learning-activity-map-your-racial-identity',
#                         'learn.mec.accept-your-identity-anti-racism-journey.learning-activity-first-thoughts',
#                         'learn.mec.accept-your-identity-anti-racism-journey.restorative-problem-solving',
#                         'learn.mec.accept-your-identity-anti-racism-journey.knowledge-check',
#                         'learn.mec.accept-your-identity-anti-racism-journey.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/accept-your-identity-anti-racism-journey/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 53,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/transform-learning-21st-century-learning-design/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/transform-learning-21st-century-learning-design.svg',
#               'last_modified': '2023-05-11T23:02:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 7,
#               'popularity': 0.670754610798273,
#               'products': ['office-365'],
#               'rating': {'average': 4.78, 'count': 6377},
#               'roles': ['k-12-educator', 'school-leader'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'Understand the concept of 21st century learning '
#                          'design. Explore learning in the 21st century and '
#                          'innovative teaching practices that support the '
#                          'development of 21st century skills.',
#               'title': 'Transform learning with 21st century learning design ',
#               'type': 'module',
#               'uid': 'learn.mec.transform-learning-21st-century-learning-design',
#               'units': ['learn.mec.transform-learning-21st-century-learning-design.introduction',
#                         'learn.mec.transform-learning-21st-century-learning-design.introduction-21st-century-learning-design',
#                         'learn.mec.transform-learning-21st-century-learning-design.examine-21st-century-learning-environments',
#                         'learn.mec.transform-learning-21st-century-learning-design.explore-research',
#                         'learn.mec.transform-learning-21st-century-learning-design.understand-21cld-rubrics',
#                         'learn.mec.transform-learning-21st-century-learning-design.knowledge-check',
#                         'learn.mec.transform-learning-21st-century-learning-design.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/transform-learning-21st-century-learning-design/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 28,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/keep-students-safe-minecraft-student-ambassador-program/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/keep-students-safe-minecraft-student-ambassador-program.svg',
#               'last_modified': '2023-05-11T23:02:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 6,
#               'popularity': 0.265492744628073,
#               'products': ['minecraft'],
#               'rating': {'average': 4.93, 'count': 116},
#               'roles': ['k-12-educator'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'Prioritizing student safety at sponsored events is '
#                          'key.  This is module 6 in the Minecraft Student '
#                          'Ambassador Program learning path.',
#               'title': 'Keep students safe in the Minecraft Student Ambassador '
#                        'program',
#               'type': 'module',
#               'uid': 'learn.mec.keep-students-safe-minecraft-student-ambassador-program',
#               'units': ['learn.mec.keep-students-safe-minecraft-student-ambassador-program.introduction',
#                         'learn.mec.keep-students-safe-minecraft-student-ambassador-program.welcome',
#                         'learn.mec.keep-students-safe-minecraft-student-ambassador-program.prioritize-safety',
#                         'learn.mec.keep-students-safe-minecraft-student-ambassador-program.case-emergency',
#                         'learn.mec.keep-students-safe-minecraft-student-ambassador-program.knowledge-check',
# ...
#                         'learn.mec.build-sel-skills-with-reflect.get-familiar-with-reflect-for-microsoft-teams',
#                         'learn.mec.build-sel-skills-with-reflect.use-reflect-in-class-notebook',
#                         'learn.mec.build-sel-skills-with-reflect.it-starts-with-you',
#                         'learn.mec.build-sel-skills-with-reflect.create-sel-kickoff-lesson-for-your-class',
#                         'learn.mec.build-sel-skills-with-reflect.knowledge-check',
#                         'learn.mec.build-sel-skills-with-reflect.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/build-sel-skills-with-reflect/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 58,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/use-power-automate-increase-productivity/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/use-power-automate-increase-productivity.svg',
#               'last_modified': '2023-05-11T23:02:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 10,
#               'popularity': 0.451211037442087,
#               'products': ['power-automate', 'office-teams', 'office-365'],
#               'rating': {'average': 4.82, 'count': 530},
#               'roles': ['k-12-educator', 'school-leader'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'Educators gain a greater understanding of what Power '
#                          'Automate is and explore what Power Automate can do. '
#                          'See how Power Automate can benefit educators '
#                          'simplify everyday tasks.',
#               'title': 'Use Power Automate to increase productivity',
#               'type': 'module',
#               'uid': 'learn.mec.use-power-automate-increase-productivity',
#               'units': ['learn.mec.use-power-automate-increase-productivity.introduction',
#                         'learn.mec.use-power-automate-increase-productivity.power-automate-education',
#                         'learn.mec.use-power-automate-increase-productivity.how-power-automate-works',
#                         'learn.mec.use-power-automate-increase-productivity.power-automate-class',
#                         'learn.mec.use-power-automate-increase-productivity.power-automate-school-level',
#                         'learn.mec.use-power-automate-increase-productivity.create-flow',
#                         'learn.mec.use-power-automate-increase-productivity.power-automate-templates',
#                         'learn.mec.use-power-automate-increase-productivity.use-power-automate-teams',
#                         'learn.mec.use-power-automate-increase-productivity.knowledge-check',
#                         'learn.mec.use-power-automate-increase-productivity.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/use-power-automate-increase-productivity/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 69,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/discover-power-apps-educators-reclaim-time/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/discover-power-apps-educators-reclaim-time.svg',
#               'last_modified': '2023-05-11T23:02:00+00:00',
#               'levels': ['intermediate'],
#               'locale': 'en-us',
#               'number_of_children': 10,
#               'popularity': 0.376404292059553,
#               'products': ['office-excel', 'office-onedrive', 'power-apps'],
#               'rating': {'average': 4.85, 'count': 114},
#               'roles': ['k-12-educator', 'school-leader'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'Educators learn how to use Power Apps by creating '
#                          'apps for themselves that help save time and create '
#                          'administrative efficiencies.',
#               'title': 'Discover Power Apps for Educators and reclaim your '
#                        'time 101',
#               'type': 'module',
#               'uid': 'learn.mec.discover-power-apps-educators-reclaim-time',
#               'units': ['learn.mec.discover-power-apps-educators-reclaim-time.introduction',
#                         'learn.mec.discover-power-apps-educators-reclaim-time.definition-power-apps',
#                         'learn.mec.discover-power-apps-educators-reclaim-time.teachers-students-solve-problems-power-apps',
#                         'learn.mec.discover-power-apps-educators-reclaim-time.create-first-app',
#                         'learn.mec.discover-power-apps-educators-reclaim-time.dig-deeper',
#                         'learn.mec.discover-power-apps-educators-reclaim-time.edit-apps-change-controls',
#                         'learn.mec.discover-power-apps-educators-reclaim-time.customize-app-further',
#                         'learn.mec.discover-power-apps-educators-reclaim-time.explore-student-information-app-mobile-device',
#                         'learn.mec.discover-power-apps-educators-reclaim-time.knowledge-check',
#                         'learn.mec.discover-power-apps-educators-reclaim-time.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/discover-power-apps-educators-reclaim-time/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 47,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/create-steam-learning-with-minecraft/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/create-steam-learning-with-minecraft.svg',
#               'last_modified': '2023-05-11T23:02:00+00:00',
#               'levels': ['intermediate'],
#               'locale': 'en-us',
#               'number_of_children': 11,
#               'popularity': 0.376124334230215,
#               'products': ['minecraft'],
#               'rating': {'average': 4.89, 'count': 229},
#               'roles': ['k-12-educator'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'This module explores how Minecraft helps embed STEAM '
#                          'elements across disciplines. It shares tips, advice, '
#                          'and resources for educators who are new to '
#                          'Minecraft, or those who need a refresher.',
#               'title': 'Create STEAM learning with Minecraft Education',
#               'type': 'module',
#               'uid': 'learn.mec.create-steam-learning-with-minecraft',
#               'units': ['learn.mec.create-steam-learning-with-minecraft.introduction',
#                         'learn.mec.create-steam-learning-with-minecraft.minecraft-education-edition-and-steam',
#                         'learn.mec.create-steam-learning-with-minecraft.use-minecraft-integrate-science-concepts-into-courses',
#                         'learn.mec.create-steam-learning-with-minecraft.use-minecraft-integrate-technology-concepts-courses',
#                         'learn.mec.create-steam-learning-with-minecraft.use-minecraft-integrate-engineering-concepts-courses',
#                         'learn.mec.create-steam-learning-with-minecraft.use-minecraft-integrate-art-concepts-into-courses',
#                         'learn.mec.create-steam-learning-with-minecraft.use-minecraft-integrate-math-concepts-courses',
#                         'learn.mec.create-steam-learning-with-minecraft.use-minecraft-create-problem-based-learning-steam-concepts',
#                         'learn.mec.create-steam-learning-with-minecraft.techniques-differentiated-instruction-minecraft',
#                         'learn.mec.create-steam-learning-with-minecraft.knowledge-check',
#                         'learn.mec.create-steam-learning-with-minecraft.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/create-steam-learning-with-minecraft/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 21,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/application-ai-with-ai-foundations-imagine-cup-junior/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/application-ai-with-ai-foundations-imagine-cup-junior.svg',
#               'last_modified': '2023-05-11T23:02:00+00:00',
#               'levels': ['intermediate'],
#               'locale': 'en-us',
#               'number_of_children': 6,
#               'popularity': 0.394344416285232,
#               'products': ['azure', 'windows'],
#               'rating': {'average': 4.75, 'count': 169},
#               'roles': ['k-12-educator'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'An introduction to how AI is applied in daily life '
#                          'and across industries, including aspects of AI such '
#                          'as NLG and speech recognition. This module is part '
#                          'of the AI Foundations: Imagine Cup Juniors learning '
#                          'path.',
#               'title': 'Application of AI with AI foundations: Imagine Cup '
#                        'Junior',
#               'type': 'module',
#               'uid': 'learn.mec.application-ai-with-ai-foundations-imagine-cup-junior',
#               'units': ['learn.mec.application-ai-with-ai-foundations-imagine-cup-junior.introduction',
#                         'learn.mec.application-ai-with-ai-foundations-imagine-cup-junior.areas-application-ai-daily-lives',
#                         'learn.mec.application-ai-with-ai-foundations-imagine-cup-junior.nlg-and-speech-recognition',
#                         'learn.mec.application-ai-with-ai-foundations-imagine-cup-junior.exposure-ai-applications-across-industry',
#                         'learn.mec.application-ai-with-ai-foundations-imagine-cup-junior.knowledge-check',
#                         'learn.mec.application-ai-with-ai-foundations-imagine-cup-junior.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/application-ai-with-ai-foundations-imagine-cup-junior/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 69,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/training/modules/enhance-social-emotional-learning-with-school-day/introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/enhance-social-emotional-learning-with-school-day.svg',
#               'last_modified': '2023-05-11T23:02:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 6,
#               'popularity': 0.390490792532128,
#               'products': ['office-teams'],
#               'rating': {'average': 4.79, 'count': 172},
#               'roles': ['k-12-educator', 'school-leader'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'Learn how social and emotional skills improve '
#                          "students' academic success and mental health. Become "
#                          'an expert on how to use School Day on Microsoft '
#                          'Teams.',
#               'title': 'Enhance social and emotional learning (SEL) with '
#                        'School Day',
#               'type': 'module',
#               'uid': 'learn.mec.enhance-social-emotional-learning-with-school-day',
#               'units': ['learn.mec.enhance-social-emotional-learning-with-school-day.introduction',
#                         'learn.mec.enhance-social-emotional-learning-with-school-day.importance-sel-student-well-being-education',
#                         'learn.mec.enhance-social-emotional-learning-with-school-day.improve-social-and-emotional-skills-in-the-classroom',
#                         'learn.mec.enhance-social-emotional-learning-with-school-day.integrate-sel-in-your-curriculum-and-schedule',
#                         'learn.mec.enhance-social-emotional-learning-with-school-day.knowledge-check',
#                         'learn.mec.enhance-social-emotional-learning-with-school-day.summary'],
#               'url': 'https://learn.microsoft.com/en-us/training/modules/enhance-social-emotional-learning-with-school-day/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 5,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/test/training/dyn365/d365-sales/instructions/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/learn/achievements/generic-badge.svg',
#               'last_modified': '2023-06-30T07:53:00+00:00',
#               'levels': ['beginner'],
#               'locale': 'en-us',
#               'number_of_children': 1,
#               'products': ['dynamics-365', 'dynamics-sales'],
#               'rating': {'count': 0},
#               'roles': ['business-user', 'functional-consultant'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'summary': 'Test module for the D365 Sales policy',
#               'title': 'Test module for the D365 Sales policy',
#               'type': 'module',
#               'uid': 'learn-ppe.dynamics.d365-sales',
#               'units': ['learn-ppe.dynamics.d365-sales.instructions'],
#               'url': 'https://learn.microsoft.com/en-us/test/training/dyn365/d365-sales/?WT.mc_id=api_CatalogApi'},
#              {'duration_in_minutes': 31,
#               'firstUnitUrl': 'https://learn.microsoft.com/en-us/test/training/azure/configure-azure-dns/1-introduction/?WT.mc_id=api_CatalogApi',
#               'icon_url': 'https://learn.microsoft.com/en-us/training/achievements/azure-dns-configure.svg',
#               'last_modified': '2023-07-20T08:28:00+00:00',
#               'levels': ['intermediate'],
#               'locale': 'en-us',
#               'number_of_children': 11,
#               'products': ['azure-dns'],
#               'rating': {'average': 2.0, 'count': 1},
#               'roles': ['administrator'],
#               'social_image_url': 'https://learn.microsoft.com/en-us/training/achievements/generic-social.png',
#               'subjects': ['networking'],
#               'summary': 'Learn how to configure Azure DNS including custom '
#                          'domain names and record sets.',
#               'title': 'Configure Azure DNS',
#               'type': 'module',
#               'uid': 'learn-test.wwl.configure-azure-dns',
#               'units': ['learn-test.wwl.configure-azure-dns.1-introduction',
#                         'learn-test.wwl.configure-azure-dns.2-identify-domains-custom-domains',
#                         'learn-test.wwl.configure-azure-dns.3-verify-custom-domain-names',
#                         'learn-test.wwl.configure-azure-dns.4-create-zones',
#                         'learn-test.wwl.configure-azure-dns.5-delegate-dns-domains',
#                         'learn-test.wwl.configure-azure-dns.6-add-dns-record-sets',
#                         'learn-test.wwl.configure-azure-dns.7-plan-for-private-dns-zones',
#                         'learn-test.wwl.configure-azure-dns.8-determine-private-zone-scenarios',
#                         'learn-test.wwl.configure-azure-dns.8a-interactive-simulation-domain-names',
#                         'learn-test.wwl.configure-azure-dns.9-knowledge-check',
#                         'learn-test.wwl.configure-azure-dns.10-summary-resources'],
#               'url': 'https://learn.microsoft.com/en-us/test/training/azure/configure-azure-dns/?WT.mc_id=api_CatalogApi'}]}

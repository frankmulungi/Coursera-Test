# %% [markdown]
# <a href="https://colab.research.google.com/github/frankmulungi/Coursera-Test/blob/master/alphavantage_apiproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np
import requests
from pprint import pprint

url = f'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=IBM&apikey=8WAK8FNJNSTN111M'

r = requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
alpha_vantage = r.json()
pprint(alpha_vantage)
# Out:
# {'Meta Data': {'1. Information': 'Monthly Prices (open, high, low, close) and '
#                                  'Volumes',
#                '2. Symbol': 'IBM',
#                '3. Last Refreshed': '2023-08-24',
#                '4. Time Zone': 'US/Eastern'},
#  'Monthly Time Series': {'1999-12-31': {'1. open': '102.5600',
#                                         '2. high': '122.1200',
#                                         '3. low': '102.2500',
#                                         '4. close': '107.8700',
#                                         '5. volume': '158626300'},
#                          '2000-01-31': {'1. open': '112.4400',
#                                         '2. high': '124.7500',
#                                         '3. low': '109.6200',
#                                         '4. close': '112.2500',
#                                         '5. volume': '175259600'},
#                          '2000-02-29': {'1. open': '112.3700',
# ...

# %%
type(r)
# Out:
# requests.models.Response

# %%
type(alpha_vantage)
# Out:
# dict

# %%
alpha_vantage.keys()
# Out:
# dict_keys(['Meta Data', 'Monthly Time Series'])

# %%
alpha_vantage['Monthly Time Series']
# Out:
# {'2023-08-24': {'1. open': '144.2500',
#   '2. high': '146.5000',
#   '3. low': '139.7600',
#   '4. close': '143.5500',
#   '5. volume': '68133955'},
#  '2023-07-31': {'1. open': '133.4200',
#   '2. high': '144.6050',
#   '3. low': '131.5500',
#   '4. close': '144.1800',
#   '5. volume': '85778938'},
#  '2023-06-30': {'1. open': '128.4400',
#   '2. high': '139.4690',
#   '3. low': '127.7800',
#   '4. close': '133.8100',
#   '5. volume': '100722016'},
#  '2023-05-31': {'1. open': '126.3500',
#   '2. high': '130.0699',
#   '3. low': '120.5500',
#   '4. close': '128.5900',
#   '5. volume': '95710890'},
#  '2023-04-28': {'1. open': '130.9700',
#   '2. high': '132.6100',
#   '3. low': '124.5600',
#   '4. close': '126.4100',
#   '5. volume': '83664114'},
#  '2023-03-31': {'1. open': '128.9000',
#   '2. high': '131.4800',
#   '3. low': '121.7100',
#   '4. close': '131.0900',
#   '5. volume': '138093084'},
#  '2023-02-28': {'1. open': '134.4900',
#   '2. high': '137.3900',
# ...

# %%
alpha_vantage['Monthly Time Series'].keys()
# Out:
# dict_keys(['2023-08-24', '2023-07-31', '2023-06-30', '2023-05-31', '2023-04-28', '2023-03-31', '2023-02-28', '2023-01-31', '2022-12-30', '2022-11-30', '2022-10-31', '2022-09-30', '2022-08-31', '2022-07-29', '2022-06-30', '2022-05-31', '2022-04-29', '2022-03-31', '2022-02-28', '2022-01-31', '2021-12-31', '2021-11-30', '2021-10-29', '2021-09-30', '2021-08-31', '2021-07-30', '2021-06-30', '2021-05-28', '2021-04-30', '2021-03-31', '2021-02-26', '2021-01-29', '2020-12-31', '2020-11-30', '2020-10-30', '2020-09-30', '2020-08-31', '2020-07-31', '2020-06-30', '2020-05-29', '2020-04-30', '2020-03-31', '2020-02-28', '2020-01-31', '2019-12-31', '2019-11-29', '2019-10-31', '2019-09-30', '2019-08-30', '2019-07-31', '2019-06-28', '2019-05-31', '2019-04-30', '2019-03-29', '2019-02-28', '2019-01-31', '2018-12-31', '2018-11-30', '2018-10-31', '2018-09-28', '2018-08-31', '2018-07-31', '2018-06-29', '2018-05-31', '2018-04-30', '2018-03-29', '2018-02-28', '2018-01-31', '2017-12-29', '2017-11-30', '2017-1
# ...

# %%
for x in alpha_vantage['Monthly Time Series']:
  print(x)
# Out:
# 2023-08-24
# 2023-07-31
# 2023-06-30
# 2023-05-31
# 2023-04-28
# 2023-03-31
# 2023-02-28
# 2023-01-31
# 2022-12-30
# 2022-11-30
# 2022-10-31
# 2022-09-30
# 2022-08-31
# 2022-07-29
# 2022-06-30
# 2022-05-31
# 2022-04-29
# 2022-03-31
# 2022-02-28
# 2022-01-31
# 2021-12-31
# 2021-11-30
# 2021-10-29
# 2021-09-30
# 2021-08-31
# 2021-07-30
# 2021-06-30
# 2021-05-28
# 2021-04-30
# 2021-03-31
# 2021-02-26
# 2021-01-29
# 2020-12-31
# 2020-11-30
# 2020-10-30
# 2020-09-30
# 2020-08-31
# 2020-07-31
# 2020-06-30
# 2020-05-29
# 2020-04-30
# 2020-03-31
# 2020-02-28
# 2020-01-31
# 2019-12-31
# 2019-11-29
# 2019-10-31
# 2019-09-30
# 2019-08-30
# 2019-07-31
# 2019-06-28
# 2019-05-31
# 2019-04-30
# 2019-03-29
# 2019-02-28
# 2019-01-31
# 2018-12-31
# 2018-11-30
# 2018-10-31
# 2018-09-28
# 2018-08-31
# 2018-07-31
# 2018-06-29
# 2018-05-31
# 2018-04-30
# 2018-03-29
# 2018-02-28
# 2018-01-31
# 2017-12-29
# 2017-11-30
# 2017-10-31
# 2017-09-29
# 2017-08-31
# 2017-07-31
# 2017-06-30
# 2017-05-31
# ...

# %%
my_frame = pd.DataFrame(alpha_vantage['Monthly Time Series'])

# %%
my_frame
# Out:
#           2023-08-24 2023-07-31 2023-06-30 2023-05-31 2023-04-28 2023-03-31  \
# 1. open     144.2500   133.4200   128.4400   126.3500   130.9700   128.9000
# 2. high     146.5000   144.6050   139.4690   130.0699   132.6100   131.4800
# 3. low      139.7600   131.5500   127.7800   120.5500   124.5600   121.7100
# 4. close    143.5500   144.1800   133.8100   128.5900   126.4100   131.0900
# 5. volume   68133955   85778938  100722016   95710890   83664114  138093084
#
#           2023-02-28 2023-01-31 2022-12-30 2022-11-30  ... 2000-09-29  \
# 1. open     134.4900   141.1000   149.9800   138.2500  ...   133.0600
# 2. high     137.3900   147.1800   153.2100   150.4600  ...   134.9400
# 3. low      128.8600   132.9800   137.1950   133.9700  ...   110.2500
# 4. close    129.3000   134.7300   140.8900   148.9000  ...   112.6200
# 5. volume   76080679  105576019   86426226   93620235  ...  107468400
#
#           2000-08-31 2000-07-31 2000-06-30 2000-05-31 2000-04-28 2000-03-31  \
# ...

# %%
plt.plot(my_frame['2023-08-24'])

# %%
my_frame.to_csv('my_frame.csv', index=False)

# %%
ls
# Out:
# my_frame.csv  sample_data/

# %%
! cat my_frame.csv
# Out:
# 2023-08-24,2023-07-31,2023-06-30,2023-05-31,2023-04-28,2023-03-31,2023-02-28,2023-01-31,2022-12-30,2022-11-30,2022-10-31,2022-09-30,2022-08-31,2022-07-29,2022-06-30,2022-05-31,2022-04-29,2022-03-31,2022-02-28,2022-01-31,2021-12-31,2021-11-30,2021-10-29,2021-09-30,2021-08-31,2021-07-30,2021-06-30,2021-05-28,2021-04-30,2021-03-31,2021-02-26,2021-01-29,2020-12-31,2020-11-30,2020-10-30,2020-09-30,2020-08-31,2020-07-31,2020-06-30,2020-05-29,2020-04-30,2020-03-31,2020-02-28,2020-01-31,2019-12-31,2019-11-29,2019-10-31,2019-09-30,2019-08-30,2019-07-31,2019-06-28,2019-05-31,2019-04-30,2019-03-29,2019-02-28,2019-01-31,2018-12-31,2018-11-30,2018-10-31,2018-09-28,2018-08-31,2018-07-31,2018-06-29,2018-05-31,2018-04-30,2018-03-29,2018-02-28,2018-01-31,2017-12-29,2017-11-30,2017-10-31,2017-09-29,2017-08-31,2017-07-31,2017-06-30,2017-05-31,2017-04-28,2017-03-31,2017-02-28,2017-01-31,2016-12-30,2016-11-30,2016-10-31,2016-09-30,2016-08-31,2016-07-29,2016-06-30,2016-05-31,2016-04-29,2016-03-31,2016-02-
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/frankmulungi/Coursera-Test/blob/master/avmost_actively_traded_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pprint import pprint
import requests

url = f'https://www.alphavantage.co/query?function=TOP_GAINERS_LOSERS&apikey=8WAK8FNJNSTN111M'

r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'metadata': 'Top gainers, losers, and most actively traded US tickers', 'last_updated': '2023-08-18 16:15:59 US/Eastern', 'top_gainers': [{'ticker': 'NCACW', 'price': '0.0385', 'change_amount': '0.0235', 'change_percentage': '156.6667%', 'volume': '14089'}, {'ticker': 'FATH+', 'price': '0.0396', 'change_amount': '0.0216', 'change_percentage': '120.0%', 'volume': '2741'}, {'ticker': 'ROSS+', 'price': '0.1388', 'change_amount': '0.0718', 'change_percentage': '107.1642%', 'volume': '33732'}, {'ticker': 'EDBLW', 'price': '0.03', 'change_amount': '0.0145', 'change_percentage': '93.5484%', 'volume': '200'}, {'ticker': 'HCDIZ', 'price': '0.0109', 'change_amount': '0.0051', 'change_percentage': '87.931%', 'volume': '100'}, {'ticker': 'MURFW', 'price': '0.1404', 'change_amount': '0.0629', 'change_percentage': '81.1613%', 'volume': '405'}, {'ticker': 'NEPT', 'price': '0.2421', 'change_amount': '0.1042', 'change_percentage': '75.562%', 'volume': '184599593'}, {'ticker': 'NSTB+', 'price': '0.04
# ...

# %%
r.status_code
# Out:
# 200

# %%
al_vantage = r.json()
pprint(al_vantage)
# Out:
# {'last_updated': '2023-08-18 16:15:59 US/Eastern',
#  'metadata': 'Top gainers, losers, and most actively traded US tickers',
#  'most_actively_traded': [{'change_amount': '0.0072',
#                            'change_percentage': '10.9422%',
#                            'price': '0.073',
#                            'ticker': 'EBET',
#                            'volume': '314623407'},
#                           {'change_amount': '0.1042',
#                            'change_percentage': '75.562%',
#                            'price': '0.2421',
#                            'ticker': 'NEPT',
#                            'volume': '184599593'},
#                           {'change_amount': '0.1067',
#                            'change_percentage': '23.5385%',
#                            'price': '0.56',
#                            'ticker': 'TTOO',
#                            'volume': '174113597'},
#                           {'change_amount': '-2.15',
# ...

# %%
type(r)
# Out:
# requests.models.Response

# %%
type(al_vantage)
# Out:
# dict

# %%
al_vantage.keys()
# Out:
# dict_keys(['metadata', 'last_updated', 'top_gainers', 'top_losers', 'most_actively_traded'])

# %%
al_vantage['most_actively_traded']
# Out:
# [{'ticker': 'EBET',
#   'price': '0.073',
#   'change_amount': '0.0072',
#   'change_percentage': '10.9422%',
#   'volume': '314623407'},
#  {'ticker': 'NEPT',
#   'price': '0.2421',
#   'change_amount': '0.1042',
#   'change_percentage': '75.562%',
#   'volume': '184599593'},
#  {'ticker': 'TTOO',
#   'price': '0.56',
#   'change_amount': '0.1067',
#   'change_percentage': '23.5385%',
#   'volume': '174113597'},
#  {'ticker': 'FTCH',
#   'price': '2.61',
#   'change_amount': '-2.15',
#   'change_percentage': '-45.1681%',
#   'volume': '166480918'},
#  {'ticker': 'SQQQ',
#   'price': '20.88',
#   'change_amount': '0.1',
#   'change_percentage': '0.4812%',
#   'volume': '163287782'},
#  {'ticker': 'TSLA',
#   'price': '215.49',
#   'change_amount': '-3.73',
#   'change_percentage': '-1.7015%',
#   'volume': '135247892'},
#  {'ticker': 'TQQQ',
#   'price': '36.4',
#   'change_amount': '-0.17',
#   'change_percentage': '-0.4649%',
#   'volume': '122562513'},
#  {'ticker': 'SPY',
# ...

# %%
for i in al_vantage['most_actively_traded']:
  print(i)
# Out:
# {'ticker': 'EBET', 'price': '0.073', 'change_amount': '0.0072', 'change_percentage': '10.9422%', 'volume': '314623407'}
# {'ticker': 'NEPT', 'price': '0.2421', 'change_amount': '0.1042', 'change_percentage': '75.562%', 'volume': '184599593'}
# {'ticker': 'TTOO', 'price': '0.56', 'change_amount': '0.1067', 'change_percentage': '23.5385%', 'volume': '174113597'}
# {'ticker': 'FTCH', 'price': '2.61', 'change_amount': '-2.15', 'change_percentage': '-45.1681%', 'volume': '166480918'}
# {'ticker': 'SQQQ', 'price': '20.88', 'change_amount': '0.1', 'change_percentage': '0.4812%', 'volume': '163287782'}
# {'ticker': 'TSLA', 'price': '215.49', 'change_amount': '-3.73', 'change_percentage': '-1.7015%', 'volume': '135247892'}
# {'ticker': 'TQQQ', 'price': '36.4', 'change_amount': '-0.17', 'change_percentage': '-0.4649%', 'volume': '122562513'}
# {'ticker': 'SPY', 'price': '436.47', 'change_amount': '0.18', 'change_percentage': '0.0413%', 'volume': '97047492'}
# ...

# %%
pd = pd.DataFrame(al_vantage["most_actively_traded"])

# %%
pd
# Out:
#    ticker   price change_amount change_percentage     volume
# 0    EBET   0.073        0.0072          10.9422%  314623407
# 1    NEPT  0.2421        0.1042           75.562%  184599593
# 2    TTOO    0.56        0.1067          23.5385%  174113597
# 3    FTCH    2.61         -2.15         -45.1681%  166480918
# 4    SQQQ   20.88           0.1           0.4812%  163287782
# 5    TSLA  215.49         -3.73          -1.7015%  135247892
# 6    TQQQ    36.4         -0.17          -0.4649%  122562513
# 7     SPY  436.47          0.18           0.0413%   97047492
# 8      WE  0.1411       -0.0168         -10.6396%   95549434
# 9    TIVC  0.0598       -0.0045          -6.9984%   95248562
# 10   KVUE   22.87          0.09           0.3951%   93260451
# 11   PLTR   14.41          0.26           1.8375%   68879280
# 12   MULN  0.6432       -0.1468         -18.5823%   68466843
# 13    NIO   10.67         -0.83          -7.2174%   67429209
# ...

# %%
def get_details(trade_info):
  try:
    url = f'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=8WAK8FNJNSTN111M'
    response = requests.get(url)
    alpha_vantage = response.json
    return alpha_vantage['information'], alpha_vantage['symbol'], alpha_vantage['last_refreshed'], alpha_vantage['interval'], alpha_vantage['output_size'], alpha_vantage['time_zone']
  except:
    return 'Error', np.NAN, np.NAN, np.NAN

# %%
r = requests.get(url)
al_vantage = r.json()
#pprint(al_vantage)

# %% [markdown]
# <a href="https://colab.research.google.com/github/frankmulungi/Coursera-Test/blob/master/pandastest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# upload dataset
project = pd.read_csv('project_dataset.csv')

project.head()
# Out:
#                                          name                     author  \
# 0                  Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                            The Burning Maze      Writtenby:RickRiordan
# 2                                The Deep End       Writtenby:JeffKinney
# 3                        Daughter of the Deep      Writtenby:RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
#
#                     narrator                time releasedate language  \
# 0      Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# 1   Narratedby:RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2      Narratedby:DanRussell    2 hrs and 3 mins    06-11-20  English
# 3  Narratedby:SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4  Narratedby:JesseBernstein              10 hrs    13-01-10  English
#
#                            stars   price
# 0     5 out of 5 stars34 ratings  468.00
# 1   4.5 out of 5 stars41 ratings  820.00
# 2   4.5 out of 5 stars38 ratings  410.00
# 3   4.5 out of 5 stars12 ratings  615.00
# 4  4.5 out of 5 stars181 ratings  820.00

# %%
# this returns the bottom 5 data in the csv file

project.tail(5)
# Out:
#                             name                    author  \
# 87484  Last Days of the Bus Club    Writtenby:ChrisStewart
# 87485                   The Alps   Writtenby:StephenO'Shea
# 87486       The Innocents Abroad       Writtenby:MarkTwain
# 87487      A Sentimental Journey  Writtenby:LaurenceSterne
# 87488                     Havana   Writtenby:MarkKurlansky
#
#                       narrator               time releasedate language  \
# 87484  Narratedby:ChrisStewart  7 hrs and 34 mins    09-03-17  English
# 87485    Narratedby:RobertFass  10 hrs and 7 mins    21-02-17  English
# 87486     Narratedby:FloGibson  19 hrs and 4 mins    30-12-16  English
# 87487   Narratedby:AntonLesser   4 hrs and 8 mins    23-02-11  English
# 87488   Narratedby:FleetCooper    6 hrs and 1 min    07-03-17  English
#
#                stars   price
# 87484  Not rated yet  596.00
# 87485  Not rated yet  820.00
# 87486  Not rated yet  938.00
# 87487  Not rated yet  680.00
# 87488  Not rated yet  569.00

# %%
# showing one column

project['author']
# Out:
# 0        Writtenby:GeronimoStilton
# 1            Writtenby:RickRiordan
# 2             Writtenby:JeffKinney
# 3            Writtenby:RickRiordan
# 4            Writtenby:RickRiordan
#                    ...
# 87484       Writtenby:ChrisStewart
# 87485      Writtenby:StephenO'Shea
# 87486          Writtenby:MarkTwain
# 87487     Writtenby:LaurenceSterne
# 87488      Writtenby:MarkKurlansky
# Name: author, Length: 87489, dtype: object

# %%
# removing writtenby from column

project['author'] = project['author'].str.replace('Writtenby:', '')

# %%
# check to see that it's gone

project['author']
# Out:
# 0        GeronimoStilton
# 1            RickRiordan
# 2             JeffKinney
# 3            RickRiordan
# 4            RickRiordan
#               ...
# 87484       ChrisStewart
# 87485      StephenO'Shea
# 87486          MarkTwain
# 87487     LaurenceSterne
# 87488      MarkKurlansky
# Name: author, Length: 87489, dtype: object

# %%
# add space to first and surname
project['author'] = project['author'].str.split(r'(?=[A-Z])').str.join(' ')

# %%
# now test it out to see that it's worked
project['author']
# Out:
# 0         Geronimo Stilton
# 1             Rick Riordan
# 2              Jeff Kinney
# 3             Rick Riordan
# 4             Rick Riordan
#                ...
# 87484        Chris Stewart
# 87485      Stephen O' Shea
# 87486           Mark Twain
# 87487      Laurence Sterne
# 87488       Mark Kurlansky
# Name: author, Length: 87489, dtype: object

# %%
# show narrator column
project['narrator']
# Out:
# 0            Narratedby:BillLobely
# 1         Narratedby:RobbieDaymond
# 2            Narratedby:DanRussell
# 3        Narratedby:SoneelaNankani
# 4        Narratedby:JesseBernstein
#                    ...
# 87484      Narratedby:ChrisStewart
# 87485        Narratedby:RobertFass
# 87486         Narratedby:FloGibson
# 87487       Narratedby:AntonLesser
# 87488       Narratedby:FleetCooper
# Name: narrator, Length: 87489, dtype: object

# %%
# clean narrator column as I did the author column

project['narrator'] = project['narrator'].str.replace('Narratedby:', '')

project['narrator'] = project['narrator'].str.split(r'(?=[A-Z])').str.join(' ')

# %%
# test output after previous steps
project['narrator']
# Out:
# 0             Bill Lobely
# 1          Robbie Daymond
# 2             Dan Russell
# 3         Soneela Nankani
# 4         Jesse Bernstein
#                ...
# 87484       Chris Stewart
# 87485         Robert Fass
# 87486          Flo Gibson
# 87487        Anton Lesser
# 87488        Fleet Cooper
# Name: narrator, Length: 87489, dtype: object

# %%
# cleaning the date format
project['releasedate'] = pd.to_datetime(project['releasedate'], format='%d-%m-%y')

# %%
# check releasedate DATE has changed

project['releasedate']
# Out:
# 0       2008-04-08
# 1       2018-01-05
# 2       2020-06-11
# 3       2021-05-10
# 4       2010-01-13
#            ...
# 87484   2017-09-03
# 87485   2017-02-21
# 87486   2016-12-30
# 87487   2011-02-23
# 87488   2017-07-03
# Name: releasedate, Length: 87489, dtype: datetime64[ns]

# %%
# create new field minutes and change time to minutes in the field
def change_time(time):
    if time == 'Less than 1 minute':
      return 0
    time = time.replace('hrs', 'hr').replace('mins', 'min')
    my_lists = time.split('and')

    hours = 0
    minutes = 0

    for my_list in my_lists:
        my_list = my_list.strip()
        if 'hr' in my_list:
            hours = int(my_list.split('hr')[0])
        if 'min' in my_list:
            minutes = int(my_list.split('min')[0])
    return hours * 60 + minutes

# %%
# testing the function above

change_time('Less than 1 minute')
# Out:
# 0

# %%
# creating rating field

project['rating'] = project['stars'].str.split().str[0].replace('Not', 0).astype(float).round().astype(int)

# %%
project['minutes'] = project['time'].apply (change_time)

# %%
import re
# project['number_of_ratings'] = project['stars'].str.split('star').str[1]

# project['number_of_ratings'] = int(re.sub("[^0-9]", "", project['stars'].str.split('star').str[1]))



def number_of_ratings_col(stars):
  rate = 0
  if str(stars).lower().strip() != 'not rated yet':
    rate = re.split('stars',str(stars))[1]
    rate = int(re.sub("[^0-9]", "",rate))
  else:
    rate = 0

  return rate

project['number_of_ratings'] = project['stars'].apply(number_of_ratings_col)

# %%
project.head()
# Out:
#                                          name             author  \
# 0                  Geronimo Stilton #11 & #12   Geronimo Stilton
# 1                            The Burning Maze       Rick Riordan
# 2                                The Deep End        Jeff Kinney
# 3                        Daughter of the Deep       Rick Riordan
# 4  The Lightning Thief: Percy Jackson, Book 1       Rick Riordan
#
#            narrator                time releasedate language  \
# 0       Bill Lobely   2 hrs and 20 mins  2008-04-08  English
# 1    Robbie Daymond   13 hrs and 8 mins  2018-01-05  English
# 2       Dan Russell    2 hrs and 3 mins  2020-06-11  English
# 3   Soneela Nankani  11 hrs and 16 mins  2021-05-10  English
# 4   Jesse Bernstein              10 hrs  2010-01-13  English
#
#                            stars   price  rating  minutes  number_of_ratings
# 0     5 out of 5 stars34 ratings  468.00       5      140                 34
# 1   4.5 out of 5 stars41 ratings  820.00       4      788                 41
# 2   4.5 out of 5 stars38 ratings  410.00       4      123                 38
# 3   4.5 out of 5 stars12 ratings  615.00       4      676                 12
# 4  4.5 out of 5 stars181 ratings  820.00       4      600                181

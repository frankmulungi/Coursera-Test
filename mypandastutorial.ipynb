# %% [markdown]
# <a href="https://colab.research.google.com/github/frankmulungi/Coursera-Test/blob/master/mypandastutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

film = pd.read_csv('2019-film-Q1.csv')

film.head()
# Out:
#    Opening  Opening.1             Title           Production company  \
# 0  JANUARY          4       Escape Room            Columbia Pictures
# 1  JANUARY          4        Rust Creek                    IFC Films
# 2  JANUARY          4  American Hangman  Hangman Justice Productions
# 3  JANUARY         11  A Dog's Way Home            Columbia Pictures
# 4  JANUARY         11        The Upside            STX Entertainment
#
#                                        Cast and crew Ref.
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]
# 3  Charles Martin Smith (director); W. Bruce Came...  [5]
# 4  Neil Burger (director); Jon Hartmere (screenpl...  [6]

# %%
film.tail()
# Out:
#    Opening  Opening.1                    Title    Production company  \
# 44   MARCH         22                 The Dirt               Netflix
# 45   MARCH         22  Dragged Across Concrete             Cinestate
# 46   MARCH         29                    Dumbo  Walt Disney Pictures
# 47   MARCH         29            The Beach Bum                  Neon
# 48   MARCH         29                Unplanned             Pure Flix
#
#                                         Cast and crew  Ref.
# 44  Jeff Tremaine (director): Tom Kapinos, Amanda ...  [46]
# 45  S. Craig Zahler (director/screenplay); Mel Gib...  [47]
# 46  Tim Burton (director); Ehren Kruger (screenpla...  [48]
# 47  Harmony Korine (director/screenplay); Matthew ...  [49]
# 48  Chuck Konzelman, Cary Soloman (director/screen...  [50]

# %%
film['new_column'] = film['Opening.1'] * 2

# %%
film.head(5)
# Out:
#    Opening  Opening.1             Title           Production company  \
# 0  JANUARY          4       Escape Room            Columbia Pictures
# 1  JANUARY          4        Rust Creek                    IFC Films
# 2  JANUARY          4  American Hangman  Hangman Justice Productions
# 3  JANUARY         11  A Dog's Way Home            Columbia Pictures
# 4  JANUARY         11        The Upside            STX Entertainment
#
#                                        Cast and crew Ref.  new_column
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]           8
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]           8
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]           8
# 3  Charles Martin Smith (director); W. Bruce Came...  [5]          22
# 4  Neil Burger (director); Jon Hartmere (screenpl...  [6]          22

# %%
film['Opening.date'] = film['Opening.1'].astype(str) + " - " + film['Opening'] + "-2019"

# %%
film.head(3)
# Out:
#    Opening  Opening.1             Title           Production company  \
# 0  JANUARY          4       Escape Room            Columbia Pictures
# 1  JANUARY          4        Rust Creek                    IFC Films
# 2  JANUARY          4  American Hangman  Hangman Justice Productions
#
#                                        Cast and crew Ref.  new_column  \
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]           8
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]           8
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]           8
#
#        Opening.date
# 0  4 - JANUARY-2019
# 1  4 - JANUARY-2019
# 2  4 - JANUARY-2019

# %%
film.dtypes
# Out:
# Opening               object
# Opening.1              int64
# Title                 object
# Production company    object
# Cast and crew         object
# Ref.                  object
# new_column             int64
# Opening.date          object
# dtype: object

# %%
film.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Opening             49 non-null     object
#  1   Opening.1           49 non-null     int64
#  2   Title               49 non-null     object
#  3   Production company  49 non-null     object
#  4   Cast and crew       49 non-null     object
#  5   Ref.                49 non-null     object
#  6   new_column          49 non-null     int64
#  7   Opening.date        49 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.2+ KB

# %%
film['Opening.date']
# Out:
# 0       4 - JANUARY-2019
# 1       4 - JANUARY-2019
# 2       4 - JANUARY-2019
# 3      11 - JANUARY-2019
# 4      11 - JANUARY-2019
# 5      11 - JANUARY-2019
# 6      15 - JANUARY-2019
# 7      18 - JANUARY-2019
# 8      18 - JANUARY-2019
# 9      18 - JANUARY-2019
# 10     24 - JANUARY-2019
# 11     25 - JANUARY-2019
# 12     25 - JANUARY-2019
# 13     25 - JANUARY-2019
# 14     26 - JANUARY-2019
# 15     1 - FEBRUARY-2019
# 16     1 - FEBRUARY-2019
# 17     1 - FEBRUARY-2019
# 18     8 - FEBRUARY-2019
# 19     8 - FEBRUARY-2019
# 20     8 - FEBRUARY-2019
# 21     8 - FEBRUARY-2019
# 22     8 - FEBRUARY-2019
# 23    13 - FEBRUARY-2019
# 24    13 - FEBRUARY-2019
# 25    14 - FEBRUARY-2019
# 26    22 - FEBRUARY-2019
# 27    22 - FEBRUARY-2019
# 28        1 - MARCH-2019
# 29        1 - MARCH-2019
# 30        6 - MARCH-2019
# 31        8 - MARCH-2019
# 32        8 - MARCH-2019
# 33       15 - MARCH-2019
# 34       15 - MARCH-2019
# 35       15 - MARCH-2019
# 36       15 - MARCH-2019
# ...

# %%
film[['Opening.date']]
# Out:
#           Opening.date
# 0     4 - JANUARY-2019
# 1     4 - JANUARY-2019
# 2     4 - JANUARY-2019
# 3    11 - JANUARY-2019
# 4    11 - JANUARY-2019
# 5    11 - JANUARY-2019
# 6    15 - JANUARY-2019
# 7    18 - JANUARY-2019
# 8    18 - JANUARY-2019
# 9    18 - JANUARY-2019
# 10   24 - JANUARY-2019
# 11   25 - JANUARY-2019
# 12   25 - JANUARY-2019
# 13   25 - JANUARY-2019
# 14   26 - JANUARY-2019
# 15   1 - FEBRUARY-2019
# 16   1 - FEBRUARY-2019
# 17   1 - FEBRUARY-2019
# 18   8 - FEBRUARY-2019
# 19   8 - FEBRUARY-2019
# 20   8 - FEBRUARY-2019
# 21   8 - FEBRUARY-2019
# 22   8 - FEBRUARY-2019
# 23  13 - FEBRUARY-2019
# 24  13 - FEBRUARY-2019
# 25  14 - FEBRUARY-2019
# 26  22 - FEBRUARY-2019
# 27  22 - FEBRUARY-2019
# 28      1 - MARCH-2019
# 29      1 - MARCH-2019
# 30      6 - MARCH-2019
# 31      8 - MARCH-2019
# 32      8 - MARCH-2019
# 33     15 - MARCH-2019
# 34     15 - MARCH-2019
# 35     15 - MARCH-2019
# 36     15 - MARCH-2019
# 37     15 - MARCH-2019
# 38     15 - MARCH-2019
# ...

# %%
# string in data series
my_column = 'Opening.date'
film[my_column]
# Out:
# 0       4 - JANUARY-2019
# 1       4 - JANUARY-2019
# 2       4 - JANUARY-2019
# 3      11 - JANUARY-2019
# 4      11 - JANUARY-2019
# 5      11 - JANUARY-2019
# 6      15 - JANUARY-2019
# 7      18 - JANUARY-2019
# 8      18 - JANUARY-2019
# 9      18 - JANUARY-2019
# 10     24 - JANUARY-2019
# 11     25 - JANUARY-2019
# 12     25 - JANUARY-2019
# 13     25 - JANUARY-2019
# 14     26 - JANUARY-2019
# 15     1 - FEBRUARY-2019
# 16     1 - FEBRUARY-2019
# 17     1 - FEBRUARY-2019
# 18     8 - FEBRUARY-2019
# 19     8 - FEBRUARY-2019
# 20     8 - FEBRUARY-2019
# 21     8 - FEBRUARY-2019
# 22     8 - FEBRUARY-2019
# 23    13 - FEBRUARY-2019
# 24    13 - FEBRUARY-2019
# 25    14 - FEBRUARY-2019
# 26    22 - FEBRUARY-2019
# 27    22 - FEBRUARY-2019
# 28        1 - MARCH-2019
# 29        1 - MARCH-2019
# 30        6 - MARCH-2019
# 31        8 - MARCH-2019
# 32        8 - MARCH-2019
# 33       15 - MARCH-2019
# 34       15 - MARCH-2019
# 35       15 - MARCH-2019
# 36       15 - MARCH-2019
# ...

# %%
# list in data frame
my_list = ['Opening.date', 'Title']
film[my_list]
# Out:
#           Opening.date                                       Title
# 0     4 - JANUARY-2019                                 Escape Room
# 1     4 - JANUARY-2019                                  Rust Creek
# 2     4 - JANUARY-2019                            American Hangman
# 3    11 - JANUARY-2019                            A Dog's Way Home
# 4    11 - JANUARY-2019                                  The Upside
# 5    11 - JANUARY-2019                                    Replicas
# 6    15 - JANUARY-2019                              After Darkness
# 7    18 - JANUARY-2019                                       Glass
# 8    18 - JANUARY-2019                                       Close
# 9    18 - JANUARY-2019               The Standoff at Sparrow Creek
# 10   24 - JANUARY-2019                              The Final Wish
# 11   25 - JANUARY-2019                   The Kid Who Would Be King
# 12   25 - JANUARY-2019                                    Serenity
# ...

# %%
type(film[['Opening.date']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(film['Opening.date'])
# Out:
# pandas.core.series.Series

# %%
# = is a a command/statement - please make this equal to this
# == is a question - is this equal to this?

film['Opening'] == 'JANUARY'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# Name: Opening, dtype: bool

# %%
mask = film['Opening'] == 'JANUARY'

# %%
# this comment - dataseries of type bool -> returns only lines that have TRUE
film[mask]
# Out:
#     Opening  Opening.1                          Title  \
# 0   JANUARY          4                    Escape Room
# 1   JANUARY          4                     Rust Creek
# 2   JANUARY          4               American Hangman
# 3   JANUARY         11               A Dog's Way Home
# 4   JANUARY         11                     The Upside
# 5   JANUARY         11                       Replicas
# 6   JANUARY         15                 After Darkness
# 7   JANUARY         18                          Glass
# 8   JANUARY         18                          Close
# 9   JANUARY         18  The Standoff at Sparrow Creek
# 10  JANUARY         24                 The Final Wish
# 11  JANUARY         25      The Kid Who Would Be King
# 12  JANUARY         25                       Serenity
# 13  JANUARY         25                    I Am Mother
# 14  JANUARY         26              The Vast of Night
#
#                                    Production company  \
# ...
